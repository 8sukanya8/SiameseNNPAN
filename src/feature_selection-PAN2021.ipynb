# %% [markdown]
# # Feature Selection
#
# This notebook helps to create the different feature selection patterns. We use Spacy to create a large document from the concatenated Training Dataset string. We are using Spacy because it is easy to filter out stuff using POS tags.

# %%
from spacy.lang.en import English
import spacy
spacy.prefer_gpu()
from collections import Counter
import csv
import config
from tqdm import tqdm
import os
import nltk
from nltk.corpus import stopwords
import re
import string
import fnmatch
from src.config import config_io
from data_processing.preprocessing import get_dataset_text# get_word_index_list, write_index_to_file, read_index_as_string

# %% [markdown]
# At first we concatenate the paragraphs of the training dataset to create a very large string called **all_text**.
# We can choose to save the file.

# %% [markdown]
# We are using Spacy to create the doc Object from the **all_text**. Now **all_text** is very large (about 196,000,000 characters or 200 million characters). Spacy has a max_length limit of 1,000,000 characters and we run into computational issues (kernel fails). As such, we must break down the document into smaller chunks. We saw that 4 million chars was manageable.
#
# Thus the idea was to create smaller documents of 4 million chars and iteratively pass them on to spacy. Spacy creates the document and we extract the tokens passed through desired filters. We could not take the naive approach to chop **all_text** into 4 M char pieces as it would lead to splitting up of terms.
#
# To avoid it, we decided to make the end point of these documents flexible, i.e the document ends at either a period or a question mark or an exclamation only. If the character at position 4M is not a (.|?|!) then we continue to look forward or backward from that point until we enocunter the mentioned punctuations.
# As a result we get slightly larger or smaller documents than 4M but no split words.
#
# We note the start and end positions in a list of tuples called the **start_end**

# %%
def get_start_end(all_text):
    count = 0
    start_point = 0
    start_end = []
    if len (all_text)< 4000000:
        return [(0, len(all_text))]
    for i in range(4000000, len(all_text), 4000000):
        print(count, i, all_text[i], all_text[i-20:i+20])
        match = re.search("\.|\?|!", all_text[i-20:i+20])
        print(match)
        if match is not None:
            end_point = i-20+match.span()[0]
        else:
            j = 10
        while match is None: # if we dont find a match, keep increasing the scope of the search text until we find a match
            if i+j+20<len(all_text):
                match = re.search("\.|\?|!", all_text[i-j-20:i+j+20])
                print(j, match, all_text[i-j-20:i+j+20])
                if match is not None:
                    end_point = i-j-20+match.span()[0]
                j+=10
            else:
                end_point = i
                break
        print("\t end point:",end_point, all_text[end_point],"finished")
        start_end.append((start_point,end_point))
        start_point = end_point
        count+=1
    return start_end

# %% [markdown]
# Code to  view the different start and end points

# %%
#[(i,j,j-i) for i,j in start_end]

# %% [markdown]
# The function **get_spacy_doc** creates and returns an NLP document with the model **en_core_web_sm**

# %%
def get_spacy_doc(text):
    #nlp = English()
    #tkr = nlp.Defaults.create_tokenizer(nlp)
    #tkr(text.lower())
    nlp = spacy.load("en_core_web_sm") #English()
    nlp.max_length = 540000000 # needs to adjust
    doc = nlp(text.lower()) 
    return doc

# %% [markdown]
# Next, we iterate over **all_text** chunk by chunk according to the **start_end** list. For each iteration we create a spacy doc using the **get_spacy_doc** function. The filter condition is used while creating the **token_list** from the doc. The terms are updated in the **term_dict**.
# We use **term_dict** to store the terms as keys and their respective counts as values in an ordered manner.
# **stopword_nltk** contains a set of stopwords from the nltk library. We compared the list of stopwords in nltk(179) and spacy(326). We found that nltk was a better choice as Spacy had too many words. We did not want to restrict so many words.

# %% [markdown]
# We can check the most common 50 terms using the code below

# %%
'''term_dict_mod1.most_common(50)'''
# Out:
# 'term_dict_mod1.most_common(50)'

# %%
def write_vocab(term_dict, folder):
    feature_set_size = [50, 100, 150, 200, 250,300,350,400,450,500]
    for i in feature_set_size:
        #folder = '/home/sukanya/PycharmProjects/SiameseNetworkTensorflow/src/baseline_with_Spacy/word_index/opt4/'
        path = folder + str(i)+"word_list.txt"
        mf_token_list = term_dict.most_common(i)
        print(mf_token_list)
        word_index_str = " ".join([k for k,v in mf_token_list])
        with open(path, "w") as file:
            file.write(word_index_str)

# %%
# combining all steps in one function
def create_vocab(training_file_path, validation_file_path, vocab_path_list):
    all_text = get_dataset_text(training_file_path,  pattern = "*") + get_dataset_text(validation_file_path,  pattern = "*")
    print("all_text len:", len(all_text))
    start_end = get_start_end(all_text)
    print(start_end)
    term_dict_mod1 = Counter()
    term_dict_mod2 = Counter()
    term_dict_mod3 = Counter()
    term_dict_mod4 = Counter()
    stopword_nltk = set(stopwords.words('english'))
    
    for start,end in start_end:
        print("\n\n", start, end, end/len(all_text)) # all_text[start: end]
        doc = get_spacy_doc(all_text[start: end])
        #Model1 (stopwords = Yes, punct = No ), check for period again after filtering
        token_list_mod1 = [token.text for token in doc if token.pos_!="PUNCT"]

        #Model2 (stopwords = Yes, punct = Yes)
        token_list_mod2 = [token.text for token in doc if token.pos_!="PUNCT" or (token.pos_=="PUNCT"and (token.text=="." or token.text==","))]

        #Model3 (stopwords = No, punct = No), check for period again after filtering
        token_list_mod3 = [token.text for token in doc if token.pos_!="PUNCT" and token.text not in stopword_nltk]

        #Model4 (stopwords = No, punct = Yes)
        token_list_mod4 = [token.text for token in doc if (token.pos_!="PUNCT" or (token.pos_=="PUNCT"and (token.text=="." or token.text==","))) and token.text not in stopword_nltk]

        term_dict_mod1.update(token_list_mod1)
        term_dict_mod2.update(token_list_mod2)
        term_dict_mod3.update(token_list_mod3)
        term_dict_mod4.update(token_list_mod4)
        print("mod1 term dict len:", len(term_dict_mod1))
        print("mod2 term dict len:", len(term_dict_mod2))
        print("mod3 term dict len:", len(term_dict_mod3))
        print("mod4 term dict len:", len(term_dict_mod4))
    #Check and filter out periods in mod1 and mod3
    
    del term_dict_mod1['.']
    del term_dict_mod3['.']
    for vocab_path ,term_dict in zip(vocab_path_list, [term_dict_mod1, term_dict_mod2, term_dict_mod3, term_dict_mod4]):
        if not os.path.exists(vocab_path):
            os.makedirs(vocab_path)
        write_vocab(term_dict, vocab_path)
    print("Writing completed!")

# %%
'''vocab_path_list = ['/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt1/',
                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt2/',
                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt3/',
                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt4/']
create_vocab(config.config_io.get('pan_20_processed_train_narrow'), vocab_path_list)'''
# Out:
# "vocab_path_list = ['/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt1/',\n                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt2/',\n                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt3/',\n                  '/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/vocab/opt4/']\ncreate_vocab(config.config_io.get('pan_20_processed_train_narrow'), vocab_path_list)"

# %%
training_file_path = config_io['pan_21_processed_train']
validation_file_path = config_io['pan_21_processed_test'] # these were validation files actually which were used for testing
vocab_base_folder_list = ['/home/sukanya/PhD/Results/012_28_Apr_PAN_21_dataset/baseline']

for vocab_base_folder in vocab_base_folder_list:
    print(training_file_path)
    vocab_path_list = [vocab_base_folder+"/"+opt for opt in ['opt1/', 'opt2/', 'opt3/', 'opt4/']]
    create_vocab(training_file_path,validation_file_path, vocab_path_list)
# Out:
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/train.csv
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/train.csv
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/test.csv
# all_text len: 40211155
# 0 4000000 i for me reliably in diverse scenarios, al
# None
# 10 None as worked for me reliably in diverse scenarios, although I s
# 20 <re.Match object; span=(7, 8), match='.'> 't work. Has worked for me reliably in diverse scenarios, although I should note
# 	 end point: 3999967 . finished
# 1 8000000 s ere are several users with a large datab
# None
# 10 None ver, if there are several users with a large database team a
# 20 <re.Match object; span=(3, 4), match='.'> ons.  However, if there are several users with a large database team and sensiti
# 	 end point: 7999963 . finished
# 2 12000000 o et to 1, and error code is set to 0. we
# <re.Match object; span=(35, 36), match='.'>
# 	 end point: 12000015 . finished
# 3 16000000 t ee different Azure Storage blob containe
# None
# 10 None I have three different Azure Storage blob containers that ar
# 20 <re.Match object; span=(7, 8), match='.'>  faster.  I have three different Azure Storage blob containers that are used to
# 	 end point: 15999967 . finished
# 4 20000000 o e using won't overflow the storage. An i
# <re.Match object; span=(34, 35), match='.'>
# 	 end point: 20000014 . finished
# 5 24000000 p ke there would be a proof of at most exp
# None
# 10 None t seems like there would be a proof of at most exponential l
# 20 <re.Match object; span=(4, 5), match='.'> swer. So it seems like there would be a proof of at most exponential length in $
# 	 end point: 23999964 . finished
# 6 28000000 t e website is VERY detailed, it's huge: h
# None
# 10 None tion on the website is VERY detailed, it's huge: https://git
# 20 <re.Match object; span=(73, 74), match='.'>  Documentation on the website is VERY detailed, it's huge: https://github.com/Sp
# 	 end point: 28000033 . finished
# 7 32000000 h  it's available to the local host, and i
# None
# 10 None means that it's available to the local host, and it cannot b
# 20 None this only means that it's available to the local host, and it cannot be used by
# 30 None  However, this only means that it's available to the local host, and it cannot be used by any other
# 40 <re.Match object; span=(9, 10), match='.'> wall here. However, this only means that it's available to the local host, and it cannot be used by any other interface.
# 	 end point: 31999949 . finished
# 8 36000000 u f yes, in which languages are those libr
# None
# 10 None braries (if yes, in which languages are those libraries avai
# 20 None pecific libraries (if yes, in which languages are those libraries available) So
# 30 None  include specific libraries (if yes, in which languages are those libraries available) So evaluating
# 40 None ire you to include specific libraries (if yes, in which languages are those libraries available) So evaluating becomes e
# 50 <re.Match object; span=(133, 134), match='.'> es it require you to include specific libraries (if yes, in which languages are those libraries available) So evaluating becomes easy. You a
# 	 end point: 36000063 . finished
# 9 40000000    also prevents using the account for Rem
# None
# 10 None , but this also prevents using the account for Remote Deskto
# 20 None omatically, but this also prevents using the account for Remote Desktop due to t
# 30 None ccount automatically, but this also prevents using the account for Remote Desktop due to the securit
# 40 None n to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy p
# 50 None s can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing
# 60 None hat Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network co
# 70 None sword so that Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network connections
# 80 None have a password so that Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network connections using acco
# 90 None t doesn't have a password so that Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network connections using accounts with
# 100 None the account doesn't have a password so that Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network connections using accounts with blank pass
# 110 <re.Match object; span=(255, 256), match='.'> nderstand the account doesn't have a password so that Windows can login to the account automatically, but this also prevents using the account for Remote Desktop due to the security policy preventing network connections using accounts with blank passwords. ...
# 	 end point: 40000125 . finished
# [(0, 3999967), (3999967, 7999963), (7999963, 12000015), (12000015, 15999967), (15999967, 20000014), (20000014, 23999964), (23999964, 28000033), (28000033, 31999949), (31999949, 36000063), (36000063, 40000125)]
#
#
#  0 3999967 0.09947406385118757
# mod1 term dict len: 24789
# mod2 term dict len: 24790
# mod3 term dict len: 24656
# mod4 term dict len: 24657
#
#
#  3999967 7999963 0.19894884889528788
# mod1 term dict len: 37095
# mod2 term dict len: 37096
# mod3 term dict len: 36954
# mod4 term dict len: 36955
#
#
#  7999963 12000015 0.2984250265877715
# mod1 term dict len: 47252
# mod2 term dict len: 47253
# mod3 term dict len: 47107
# mod4 term dict len: 47108
#
#
#  12000015 15999967 0.3978987174081421
# mod1 term dict len: 56380
# mod2 term dict len: 56381
# mod3 term dict len: 56234
# mod4 term dict len: 56235
#
#
#  15999967 20000014 0.49737477075702
# mod1 term dict len: 58657
# mod2 term dict len: 58658
# mod3 term dict len: 58511
# mod4 term dict len: 58512
#
#
#  20000014 23999964 0.5968484118399484
# mod1 term dict len: 60022
# mod2 term dict len: 60023
# mod3 term dict len: 59875
# mod4 term dict len: 59876
#
#
#  23999964 28000033 0.6963250123006912
# mod1 term dict len: 61316
# mod2 term dict len: 61317
# mod3 term dict len: 61169
# mod4 term dict len: 61170
#
#
#  28000033 31999949 0.7957978078471011
# mod1 term dict len: 62571
# mod2 term dict len: 62572
# mod3 term dict len: 62424
# mod4 term dict len: 62425
#
#
#  31999949 36000063 0.8952755274002948
# mod1 term dict len: 68924
# mod2 term dict len: 68925
# mod3 term dict len: 68777
# mod4 term dict len: 68778
#
#
#  36000063 40000125 0.9947519537799897
# mod1 term dict len: 71409
# mod2 term dict len: 71410
# mod3 term dict len: 71261
# mod4 term dict len: 71262
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756)]
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736)]
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797)]
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555)]
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('doing', 4555), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('too', 4390), ('off', 4372), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('why', 4330), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('were', 4202), ('single', 4171), ('having', 4170), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('own', 4010), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833),  ...
# [('the', 368276), ('.', 316150), (',', 285574), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266)]
# [('the', 368276), ('.', 316150), (',', 285574), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791)]
# [('the', 368276), ('.', 316150), (',', 285574), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902)]
# [('the', 368276), ('.', 316150), (',', 285574), ('to', 238498), ('a', 179162), ('and', 145319), ('you', 138802), ('is', 124624), ('i', 121994), ('of', 113651), ('it', 113477), ('that', 102476), ('in', 90728), ('for', 73091), (' ', 67062), ('on', 65704), ('this', 61365), ('be', 59081), ('if', 56218), ('have', 53799), ('with', 52423), ('your', 51612), ('can', 48714), ('as', 47817), ('not', 45618), ('are', 45548), ('but', 42639), ('or', 40123), ("'s", 38447), ("n't", 38406), ('do', 37753), ('will', 33370), ('from', 29948), ('so', 29307), ('an', 29086), ('use', 26692), ('would', 26055), ('/', 25908), ('there', 25739), ('server', 25421), ('one', 24123), ('all', 23846), ('at', 23669), ('my', 23521), ('which', 23336), ('then', 23090), ('by', 20789), ('what', 19805), ('when', 19571), ('some', 19266), ('like', 18878), ('using', 18756), ('they', 18395), ('just', 18222), ('need', 17425), ('up', 17243), ('only', 17076), ('more', 16196), ('any', 16011), ('other', 16002), ('also', 15950), ('should', 15711), ('has', 15359), ('does', 14949), ('get', 14914), ('was', 14821), ('windows', 14820), ('data', 14805), ('want', 14167), ('we', 13855), ('time', 13774), ('could', 13687), ('file', 13681), ('no', 12849), ('way', 12667), ('same', 12591), ('out', 12225), ('how', 12172), ('them', 12062), ('about', 11714), ('system', 11227), ('network', 10978), ('into', 10974), ('make', 10966), ('than', 10880), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('each', 9485), ('because', 9474), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('where', 8427), ('might', 8231), ('very', 8217), ('these', 8144), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('now', 7637), ('their', 7416), ('most', 7396), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('me', 7086), ('well', 7059), ('another', 6960), ('good', 6947), ('here', 6817), ('able', 6764), ('after', 6700), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('its', 6542), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('had', 6355), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('both', 6135), ('over', 6077), ('without', 6048), ('go', 6047), ('am', 6039), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ('such', 5797), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('been', 5477), ('ca', 5454), ('etc', 5451), ('those', 5408), ('going', 5392), ('things', 5388), ('create', 5368), ('being', 5345), ('through', 5282), ('while', 5246), ('between', 5227), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('did', 5011), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('before', 4919), ('down', 4866), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('our', 4632), ('take', 4605), ('issue', 4603), ('lot', 4595)]
# ...
# [('.', 316150), (',', 285574), (' ', 67062), ("'s", 38447), ("n't", 38406), ('use', 26692), ('would', 26055), ('/', 25908), ('server', 25421), ('one', 24123), ('like', 18878), ('using', 18756), ('need', 17425), ('also', 15950), ('get', 14914), ('windows', 14820), ('data', 14805), ('want', 14167), ('time', 13774), ('could', 13687), ('file', 13681), ('way', 12667), ('system', 11227), ('network', 10978), ('make', 10966), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('might', 8231), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('well', 7059), ('another', 6960), ('good', 6947), ('able', 6764), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('without', 6048), ('go', 6047), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('ca', 5454), ('etc', 5451), ('going', 5392), ('things', 5388), ('create', 5368), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('single', 4171), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833), ('open', 3826), ('already', 3783), ('traffic', 3772), ('information', 3761), ('second', 3748), ('always', 3745), ('answer', 3743), ('device', 3712), ('internet', 3704), ('working', 3689), ('anything', 3687), ('keep', 3687), ('done', 3672), ('hardware', 3645), ('sql', 3628), ('found', 3606), ('bit', 3597), ('give', 3593), ('support', 3566), ('log', 3561), ('connect', 3551), ('error', 3549), ('via', 3544), ('switch', 3540), ('around', 3530), ('line', 3518), ('directory', 3510), ('setup', 3508), ('seems', 3480), ('multiple', 3479), ('list', 3454), ('help', 3423), ('installed', 3417), ('specific', 3410), ('configuration', 3403), ('everything', 3391), ('load', 3381), ('script', 3377), ('long', 3376), ('looking', 3375), ('people', 3371), ('type', 3364), ('space', 3363), ('site', 3363), ('3', 3350), ('means', 3348), ('usually', 3332), ('write', 3317), ('wo', 3308), ('boot', 3306), ('>', 3300), ('simple', 3300), ('test', 3267), ('old', 3251), ('program', 3239), ('level', 3233), ('cpu', 3228), ('instance', 3198), ('available', 3198), ('security', 3194), ('allow', 3168), ('copy', 3160), ('put', 3148), ('usb', 3141), ('function', 3133), ('enough', 3110), ('update', 3110), ('gb', 3088), ('least', 3085), ('value', 3037), ('size', 3012), ('partition', 3004), ('similar', 2997), ('settings', 2970), ('tried', 2967), ('reason', 2966), ('less', 2960), ('part', 2956), ('likely', 2950), ('problems', 2935), ('small', 2920), ('fine', 2915), ('needs', 2911), ('source', 2907), ('virtual', 2899), ('le ...
# [('.', 316150), (',', 285574), (' ', 67062), ("'s", 38447), ("n't", 38406), ('use', 26692), ('would', 26055), ('/', 25908), ('server', 25421), ('one', 24123), ('like', 18878), ('using', 18756), ('need', 17425), ('also', 15950), ('get', 14914), ('windows', 14820), ('data', 14805), ('want', 14167), ('time', 13774), ('could', 13687), ('file', 13681), ('way', 12667), ('system', 11227), ('network', 10978), ('make', 10966), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('might', 8231), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('well', 7059), ('another', 6960), ('good', 6947), ('able', 6764), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('without', 6048), ('go', 6047), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('ca', 5454), ('etc', 5451), ('going', 5392), ('things', 5388), ('create', 5368), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('single', 4171), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833), ('open', 3826), ('already', 3783), ('traffic', 3772), ('information', 3761), ('second', 3748), ('always', 3745), ('answer', 3743), ('device', 3712), ('internet', 3704), ('working', 3689), ('anything', 3687), ('keep', 3687), ('done', 3672), ('hardware', 3645), ('sql', 3628), ('found', 3606), ('bit', 3597), ('give', 3593), ('support', 3566), ('log', 3561), ('connect', 3551), ('error', 3549), ('via', 3544), ('switch', 3540), ('around', 3530), ('line', 3518), ('directory', 3510), ('setup', 3508), ('seems', 3480), ('multiple', 3479), ('list', 3454), ('help', 3423), ('installed', 3417), ('specific', 3410), ('configuration', 3403), ('everything', 3391), ('load', 3381), ('script', 3377), ('long', 3376), ('looking', 3375), ('people', 3371), ('type', 3364), ('space', 3363), ('site', 3363), ('3', 3350), ('means', 3348), ('usually', 3332), ('write', 3317), ('wo', 3308), ('boot', 3306), ('>', 3300), ('simple', 3300), ('test', 3267), ('old', 3251), ('program', 3239), ('level', 3233), ('cpu', 3228), ('instance', 3198), ('available', 3198), ('security', 3194), ('allow', 3168), ('copy', 3160), ('put', 3148), ('usb', 3141), ('function', 3133), ('enough', 3110), ('update', 3110), ('gb', 3088), ('least', 3085), ('value', 3037), ('size', 3012), ('partition', 3004), ('similar', 2997), ('settings', 2970), ('tried', 2967), ('reason', 2966), ('less', 2960), ('part', 2956), ('likely', 2950), ('problems', 2935), ('small', 2920), ('fine', 2915), ('needs', 2911), ('source', 2907), ('virtual', 2899), ('le ...
# [('.', 316150), (',', 285574), (' ', 67062), ("'s", 38447), ("n't", 38406), ('use', 26692), ('would', 26055), ('/', 25908), ('server', 25421), ('one', 24123), ('like', 18878), ('using', 18756), ('need', 17425), ('also', 15950), ('get', 14914), ('windows', 14820), ('data', 14805), ('want', 14167), ('time', 13774), ('could', 13687), ('file', 13681), ('way', 12667), ('system', 11227), ('network', 10978), ('make', 10966), ('work', 10657), ("'m", 10539), ('may', 10382), ('problem', 10122), ("'re", 9922), ('see', 9848), ('set', 9756), ('files', 9595), ('run', 9345), ('new', 9328), ("'ve", 9203), ('ip', 8843), ('-', 8791), ('used', 8777), ('different', 8736), ('even', 8650), ('user', 8504), ('know', 8438), ('might', 8231), ('running', 8095), ('first', 8087), ('two', 7903), ('something', 7761), ('access', 7738), ('drive', 7380), ('much', 7222), ('case', 7178), ('code', 7120), ('well', 7059), ('another', 6960), ('good', 6947), ('able', 6764), ('machine', 6691), ('find', 6674), ('really', 6600), ('sure', 6582), ('try', 6460), ('however', 6426), ('still', 6412), ('address', 6405), ('since', 6308), ('$', 6269), ('think', 6253), ('computer', 6225), ('without', 6048), ('go', 6047), ('example', 6009), ('disk', 5915), ('many', 5902), ('servers', 5812), ("'d", 5771), ("'ll", 5699), ('2', 5667), ('1', 5652), ('probably', 5629), ('change', 5594), ('router', 5555), ('possible', 5515), ('ca', 5454), ('etc', 5451), ('going', 5392), ('things', 5388), ('create', 5368), ('number', 5206), ('look', 5173), ('point', 5172), ('back', 5153), ('domain', 5143), ('database', 5134), ('client', 5089), ('add', 5054), ('software', 5004), ('install', 5002), ('port', 4993), ('check', 4990), ('linux', 4970), ('start', 4954), ('better', 4923), ('dns', 4862), ('question', 4816), ('connection', 4799), ('solution', 4707), ('right', 4677), ('every', 4660), ('application', 4635), ('take', 4605), ('issue', 4603), ('lot', 4595), ('users', 4583), ('name', 4529), ('either', 4465), ('actually', 4434), ('instead', 4394), ('read', 4355), ('process', 4352), ('  ', 4342), ('table', 4331), ('based', 4303), ('thing', 4288), ('hard', 4276), ('command', 4226), ('key', 4225), ('game', 4216), ('works', 4208), ('single', 4171), ('performance', 4152), ('memory', 4150), ('web', 4150), ('best', 4123), ('host', 4103), ('say', 4088), ('though', 4082), ('option', 4077), ('default', 4061), ('end', 4010), ('power', 3974), ('trying', 3934), ('local', 3933), ('version', 3927), ('service', 3846), ('backup', 3834), ('os', 3833), ('open', 3826), ('already', 3783), ('traffic', 3772), ('information', 3761), ('second', 3748), ('always', 3745), ('answer', 3743), ('device', 3712), ('internet', 3704), ('working', 3689), ('anything', 3687), ('keep', 3687), ('done', 3672), ('hardware', 3645), ('sql', 3628), ('found', 3606), ('bit', 3597), ('give', 3593), ('support', 3566), ('log', 3561), ('connect', 3551), ('error', 3549), ('via', 3544), ('switch', 3540), ('around', 3530), ('line', 3518), ('directory', 3510), ('setup', 3508), ('seems', 3480), ('multiple', 3479), ('list', 3454), ('help', 3423), ('installed', 3417), ('specific', 3410), ('configuration', 3403), ('everything', 3391), ('load', 3381), ('script', 3377), ('long', 3376), ('looking', 3375), ('people', 3371), ('type', 3364), ('space', 3363), ('site', 3363), ('3', 3350), ('means', 3348), ('usually', 3332), ('write', 3317), ('wo', 3308), ('boot', 3306), ('>', 3300), ('simple', 3300), ('test', 3267), ('old', 3251), ('program', 3239), ('level', 3233), ('cpu', 3228), ('instance', 3198), ('available', 3198), ('security', 3194), ('allow', 3168), ('copy', 3160), ('put', 3148), ('usb', 3141), ('function', 3133), ('enough', 3110), ('update', 3110), ('gb', 3088), ('least', 3085), ('value', 3037), ('size', 3012), ('partition', 3004), ('similar', 2997), ('settings', 2970), ('tried', 2967), ('reason', 2966), ('less', 2960), ('part', 2956), ('likely', 2950), ('problems', 2935), ('small', 2920), ('fine', 2915), ('needs', 2911), ('source', 2907), ('virtual', 2899), ('le ...
# Writing completed!

# %% [markdown]
# Anything beyond this point is old code that is not required.

# %%
training_files = [config_io['pan_21_processed_train']]

vocab_base_folder_list = ['/home/sukanya/PhD/Results/012_28_Apr_PAN_21_dataset/baseline']


for training_file_path,vocab_base_folder in zip(training_files, vocab_base_folder_list):
    print(training_file_path)
    vocab_path_list = [vocab_base_folder+"/"+opt for opt in ['opt1/', 'opt2/', 'opt3/', 'opt4/']]
    create_vocab(training_file_path, vocab_path_list)
# Out:
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/train.csv
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/train.csv
# all_text len: 33110363
# 0 4000000 i for me reliably in diverse scenarios, al
# None
# 10 None as worked for me reliably in diverse scenarios, although I s
# 20 <re.Match object; span=(7, 8), match='.'> 't work. Has worked for me reliably in diverse scenarios, although I should note
# 	 end point: 3999967 . finished
# 1 8000000 s ere are several users with a large datab
# None
# 10 None ver, if there are several users with a large database team a
# 20 <re.Match object; span=(3, 4), match='.'> ons.  However, if there are several users with a large database team and sensiti
# 	 end point: 7999963 . finished
# 2 12000000 o et to 1, and error code is set to 0. we
# <re.Match object; span=(35, 36), match='.'>
# 	 end point: 12000015 . finished
# 3 16000000 t ee different Azure Storage blob containe
# None
# 10 None I have three different Azure Storage blob containers that ar
# 20 <re.Match object; span=(7, 8), match='.'>  faster.  I have three different Azure Storage blob containers that are used to
# 	 end point: 15999967 . finished
# 4 20000000 o e using won't overflow the storage. An i
# <re.Match object; span=(34, 35), match='.'>
# 	 end point: 20000014 . finished
# 5 24000000 p ke there would be a proof of at most exp
# None
# 10 None t seems like there would be a proof of at most exponential l
# 20 <re.Match object; span=(4, 5), match='.'> swer. So it seems like there would be a proof of at most exponential length in $
# 	 end point: 23999964 . finished
# 6 28000000 t e website is VERY detailed, it's huge: h
# None
# 10 None tion on the website is VERY detailed, it's huge: https://git
# 20 <re.Match object; span=(73, 74), match='.'>  Documentation on the website is VERY detailed, it's huge: https://github.com/Sp
# 	 end point: 28000033 . finished
# 7 32000000 h  it's available to the local host, and i
# None
# 10 None means that it's available to the local host, and it cannot b
# 20 None this only means that it's available to the local host, and it cannot be used by
# 30 None  However, this only means that it's available to the local host, and it cannot be used by any other
# 40 <re.Match object; span=(9, 10), match='.'> wall here. However, this only means that it's available to the local host, and it cannot be used by any other interface.
# 	 end point: 31999949 . finished
# [(0, 3999967), (3999967, 7999963), (7999963, 12000015), (12000015, 15999967), (15999967, 20000014), (20000014, 23999964), (23999964, 28000033), (28000033, 31999949)]
#
#
#  0 3999967 0.12080710199401921
# mod1 term dict len: 24789
# mod2 term dict len: 24790
# mod3 term dict len: 24656
# mod4 term dict len: 24657
#
#
#  3999967 7999963 0.2416150798467537
# mod1 term dict len: 37095
# mod2 term dict len: 37096
# mod3 term dict len: 36954
# mod4 term dict len: 36955
#
#
#  7999963 12000015 0.3624247490128695
# mod1 term dict len: 47252
# mod2 term dict len: 47253
# mod3 term dict len: 47107
# mod4 term dict len: 47108
#
#
#  12000015 15999967 0.4832313979765187
# mod1 term dict len: 56380
# mod2 term dict len: 56381
# mod3 term dict len: 56234
# mod4 term dict len: 56235
#
#
#  15999967 20000014 0.6040409161325111
# mod1 term dict len: 58657
# mod2 term dict len: 58658
# mod3 term dict len: 58511
# mod4 term dict len: 58512
#
#
#  20000014 23999964 0.724847504692111
# mod1 term dict len: 60022
# mod2 term dict len: 60023
# mod3 term dict len: 59875
# mod4 term dict len: 59876
#
#
#  23999964 28000033 0.8456576872926461
# mod1 term dict len: 61316
# mod2 term dict len: 61317
# mod3 term dict len: 61169
# mod4 term dict len: 61170
#
#
#  28000033 31999949 0.9664632489834074
# mod1 term dict len: 62571
# mod2 term dict len: 62572
# mod3 term dict len: 62424
# mod4 term dict len: 62425
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958)]
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993)]
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619)]
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645)]
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('too', 3578), ('off', 3553), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('why', 3417), ('hard', 3413), ('having', 3395), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('were', 3319), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('own', 3258), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet',  ...
# [('the', 295096), ('.', 252557), (',', 228021), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536)]
# [('the', 295096), ('.', 252557), (',', 228021), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076)]
# [('the', 295096), ('.', 252557), (',', 228021), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685)]
# [('the', 295096), ('.', 252557), (',', 228021), ('to', 191098), ('a', 143626), ('and', 116005), ('you', 110970), ('is', 99903), ('i', 97246), ('of', 90894), ('it', 90397), ('that', 82278), ('in', 72859), ('for', 58294), (' ', 53602), ('on', 52517), ('this', 49069), ('be', 47539), ('if', 44787), ('have', 42934), ('with', 41925), ('your', 41335), ('can', 38953), ('as', 38105), ('not', 36459), ('are', 36355), ('but', 34100), ('or', 32124), ("n't", 30754), ("'s", 30413), ('do', 30210), ('will', 26653), ('from', 24029), ('so', 23449), ('an', 23343), ('use', 21328), ('would', 20930), ('/', 20865), ('there', 20679), ('server', 20461), ('one', 19287), ('all', 19052), ('at', 18850), ('my', 18796), ('which', 18685), ('then', 18517), ('by', 16614), ('when', 15774), ('what', 15679), ('some', 15536), ('like', 15100), ('using', 14958), ('they', 14529), ('just', 14487), ('need', 13970), ('up', 13801), ('only', 13626), ('more', 12883), ('other', 12805), ('any', 12772), ('also', 12680), ('should', 12553), ('has', 12317), ('was', 12021), ('does', 11971), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('we', 11158), ('could', 10997), ('file', 10927), ('time', 10870), ('no', 10315), ('way', 10206), ('same', 10143), ('out', 9717), ('how', 9693), ('them', 9441), ('about', 9347), ('system', 8990), ('into', 8843), ('network', 8787), ('make', 8767), ('than', 8670), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('each', 7625), ('because', 7557), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('where', 6799), ('know', 6708), ('might', 6595), ('very', 6589), ('these', 6562), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('now', 6070), ('most', 5908), ('their', 5851), ('drive', 5798), ('case', 5781), ('me', 5723), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('after', 5439), ('here', 5413), ('really', 5363), ('sure', 5275), ('its', 5254), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('had', 5063), ('since', 5061), ('both', 4864), ('over', 4848), ('am', 4847), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ('such', 4610), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('been', 4363), ('ca', 4357), ('being', 4336), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('those', 4251), ('number', 4246), ('database', 4239), ('between', 4223), ('while', 4210), ('through', 4201), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('did', 3991), ('check', 3955), ('install', 3948), ('start', 3942), ('before', 3929), ('add', 3927), ('dns', 3916), ('down', 3888), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('our', 3706), ('doing', 3683), ('take', 3668)]
# ...
# [('.', 252557), (',', 228021), (' ', 53602), ("n't", 30754), ("'s", 30413), ('use', 21328), ('would', 20930), ('/', 20865), ('server', 20461), ('one', 19287), ('like', 15100), ('using', 14958), ('need', 13970), ('also', 12680), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('could', 10997), ('file', 10927), ('time', 10870), ('way', 10206), ('system', 8990), ('network', 8787), ('make', 8767), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('know', 6708), ('might', 6595), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('drive', 5798), ('case', 5781), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('really', 5363), ('sure', 5275), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('since', 5061), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('ca', 4357), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('number', 4246), ('database', 4239), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('check', 3955), ('install', 3948), ('start', 3942), ('add', 3927), ('dns', 3916), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('hard', 3413), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet', 3037), ('os', 3014), ('answer', 3005), ('always', 3003), ('open', 2996), ('second', 2995), ('information', 2986), ('working', 2981), ('device', 2981), ('done', 2975), ('already', 2947), ('anything', 2927), ('switch', 2922), ('bit', 2914), ('keep', 2900), ('found', 2898), ('sql', 2895), ('line', 2888), ('log', 2885), ('around', 2884), ('hardware', 2865), ('connect', 2863), ('give', 2847), ('via', 2846), ('setup', 2829), ('error', 2821), ('directory', 2821), ('support', 2804), ('seems', 2793), ('multiple', 2784), ('specific', 2749), ('3', 2739), ('installed', 2735), ('site', 2709), ('load', 2707), ('everything', 2701), ('test', 2697), ('space', 2690), ('looking', 2688), ('list', 2688), ('configuration', 2686), ('script', 2686), ('long', 2686), ('help', 2685), ('wo', 2684), ('people', 2676), ('cpu', 2669), ('usually', 2663), ('simple', 2661), ('means', 2641), ('level', 2626), ('write', 2611), ('>', 2606), ('boot', 2585), ('type', 2582), ('available', 2579), ('security', 2576), ('old', 2568), ('program', 2560), ('update', 2539), ('allow', 2527), ('usb', 2513), ('put', 2512), ('function', 2511), ('instance', 2496), ('partition', 2493), ('copy', 2470), ('least', 2462), ('value', 2460), ('gb', 2454), ('enough', 2449), ('part', 2419), ('similar', 2413), ('likely', 2405), ('settings', 2400), ('tried', 2388), ('reason', 2357), ('virtual', 2355), ('size', 2355), ('problems', 2345), ('page', 2345), ('small', 2343), ('full', 2331), ('less', 2331), ('needs', 2313), ('interface', ...
# [('.', 252557), (',', 228021), (' ', 53602), ("n't", 30754), ("'s", 30413), ('use', 21328), ('would', 20930), ('/', 20865), ('server', 20461), ('one', 19287), ('like', 15100), ('using', 14958), ('need', 13970), ('also', 12680), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('could', 10997), ('file', 10927), ('time', 10870), ('way', 10206), ('system', 8990), ('network', 8787), ('make', 8767), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('know', 6708), ('might', 6595), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('drive', 5798), ('case', 5781), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('really', 5363), ('sure', 5275), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('since', 5061), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('ca', 4357), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('number', 4246), ('database', 4239), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('check', 3955), ('install', 3948), ('start', 3942), ('add', 3927), ('dns', 3916), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('hard', 3413), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet', 3037), ('os', 3014), ('answer', 3005), ('always', 3003), ('open', 2996), ('second', 2995), ('information', 2986), ('working', 2981), ('device', 2981), ('done', 2975), ('already', 2947), ('anything', 2927), ('switch', 2922), ('bit', 2914), ('keep', 2900), ('found', 2898), ('sql', 2895), ('line', 2888), ('log', 2885), ('around', 2884), ('hardware', 2865), ('connect', 2863), ('give', 2847), ('via', 2846), ('setup', 2829), ('error', 2821), ('directory', 2821), ('support', 2804), ('seems', 2793), ('multiple', 2784), ('specific', 2749), ('3', 2739), ('installed', 2735), ('site', 2709), ('load', 2707), ('everything', 2701), ('test', 2697), ('space', 2690), ('looking', 2688), ('list', 2688), ('configuration', 2686), ('script', 2686), ('long', 2686), ('help', 2685), ('wo', 2684), ('people', 2676), ('cpu', 2669), ('usually', 2663), ('simple', 2661), ('means', 2641), ('level', 2626), ('write', 2611), ('>', 2606), ('boot', 2585), ('type', 2582), ('available', 2579), ('security', 2576), ('old', 2568), ('program', 2560), ('update', 2539), ('allow', 2527), ('usb', 2513), ('put', 2512), ('function', 2511), ('instance', 2496), ('partition', 2493), ('copy', 2470), ('least', 2462), ('value', 2460), ('gb', 2454), ('enough', 2449), ('part', 2419), ('similar', 2413), ('likely', 2405), ('settings', 2400), ('tried', 2388), ('reason', 2357), ('virtual', 2355), ('size', 2355), ('problems', 2345), ('page', 2345), ('small', 2343), ('full', 2331), ('less', 2331), ('needs', 2313), ('interface', ...
# [('.', 252557), (',', 228021), (' ', 53602), ("n't", 30754), ("'s", 30413), ('use', 21328), ('would', 20930), ('/', 20865), ('server', 20461), ('one', 19287), ('like', 15100), ('using', 14958), ('need', 13970), ('also', 12680), ('get', 11872), ('windows', 11812), ('data', 11746), ('want', 11274), ('could', 10997), ('file', 10927), ('time', 10870), ('way', 10206), ('system', 8990), ('network', 8787), ('make', 8767), ('work', 8447), ("'m", 8408), ('may', 8380), ('problem', 8136), ('see', 7828), ("'re", 7816), ('set', 7816), ('files', 7635), ('new', 7518), ('run', 7474), ("'ve", 7318), ('different', 7101), ('-', 7076), ('ip', 7015), ('used', 6993), ('even', 6909), ('user', 6875), ('know', 6708), ('might', 6595), ('running', 6509), ('first', 6425), ('two', 6336), ('access', 6225), ('something', 6177), ('drive', 5798), ('case', 5781), ('much', 5718), ('code', 5671), ('well', 5645), ('another', 5642), ('good', 5554), ('machine', 5509), ('able', 5452), ('really', 5363), ('sure', 5275), ('find', 5213), ('however', 5184), ('try', 5174), ('address', 5165), ('$', 5128), ('computer', 5127), ('still', 5095), ('think', 5086), ('since', 5061), ('go', 4844), ('many', 4793), ('without', 4754), ('example', 4741), ('servers', 4685), ('router', 4679), ('2', 4619), ("'d", 4606), ('1', 4601), ('disk', 4582), ('probably', 4526), ("'ll", 4499), ('change', 4494), ('possible', 4411), ('ca', 4357), ('going', 4333), ('create', 4325), ('etc', 4308), ('things', 4289), ('number', 4246), ('database', 4239), ('point', 4186), ('look', 4122), ('client', 4097), ('back', 4094), ('domain', 4091), ('software', 4016), ('port', 4006), ('check', 3955), ('install', 3948), ('start', 3942), ('add', 3927), ('dns', 3916), ('question', 3882), ('better', 3880), ('linux', 3875), ('connection', 3830), ('application', 3821), ('every', 3751), ('issue', 3745), ('solution', 3732), ('right', 3719), ('take', 3668), ('users', 3646), ('lot', 3645), ('either', 3608), ('name', 3600), ('process', 3528), ('  ', 3511), ('actually', 3498), ('instead', 3487), ('table', 3475), ('game', 3469), ('thing', 3467), ('read', 3453), ('based', 3445), ('hard', 3413), ('command', 3373), ('performance', 3373), ('memory', 3354), ('single', 3340), ('though', 3333), ('works', 3313), ('power', 3306), ('key', 3293), ('host', 3271), ('default', 3266), ('option', 3266), ('best', 3263), ('web', 3251), ('say', 3223), ('end', 3192), ('local', 3167), ('trying', 3166), ('version', 3124), ('service', 3094), ('traffic', 3058), ('backup', 3048), ('internet', 3037), ('os', 3014), ('answer', 3005), ('always', 3003), ('open', 2996), ('second', 2995), ('information', 2986), ('working', 2981), ('device', 2981), ('done', 2975), ('already', 2947), ('anything', 2927), ('switch', 2922), ('bit', 2914), ('keep', 2900), ('found', 2898), ('sql', 2895), ('line', 2888), ('log', 2885), ('around', 2884), ('hardware', 2865), ('connect', 2863), ('give', 2847), ('via', 2846), ('setup', 2829), ('error', 2821), ('directory', 2821), ('support', 2804), ('seems', 2793), ('multiple', 2784), ('specific', 2749), ('3', 2739), ('installed', 2735), ('site', 2709), ('load', 2707), ('everything', 2701), ('test', 2697), ('space', 2690), ('looking', 2688), ('list', 2688), ('configuration', 2686), ('script', 2686), ('long', 2686), ('help', 2685), ('wo', 2684), ('people', 2676), ('cpu', 2669), ('usually', 2663), ('simple', 2661), ('means', 2641), ('level', 2626), ('write', 2611), ('>', 2606), ('boot', 2585), ('type', 2582), ('available', 2579), ('security', 2576), ('old', 2568), ('program', 2560), ('update', 2539), ('allow', 2527), ('usb', 2513), ('put', 2512), ('function', 2511), ('instance', 2496), ('partition', 2493), ('copy', 2470), ('least', 2462), ('value', 2460), ('gb', 2454), ('enough', 2449), ('part', 2419), ('similar', 2413), ('likely', 2405), ('settings', 2400), ('tried', 2388), ('reason', 2357), ('virtual', 2355), ('size', 2355), ('problems', 2345), ('page', 2345), ('small', 2343), ('full', 2331), ('less', 2331), ('needs', 2313), ('interface', ...
# Writing completed!

# %%
for training_file_path,vocab_base_folder in zip(training_files, vocab_base_folder_list):
    print (training_file_path, vocab_base_folder)
# Out:
# /home/sukanya/PhD/Datasets/PAN SCD/pan21-style-change-detection/processed/train.csv /home/sukanya/PhD/Results/011_16_Apr_PAN_21_dataset/vocab/

# %%
training_files[-1:]
# Out:
# ['/home/sukanya/PhD/Results/010_22_Feb_PAN_dataset_MPL_based/datasets/training_2000.csv']

# %% [markdown]
# Compare the saved models for 500 vocab sizes for respective models

# %%
mod1_pan = "/home/sukanya/PycharmProjects/SiameseNNPAN/src/word_index/opt1/500word_list.txt"
mod2_pan = "/home/sukanya/PycharmProjects/SiameseNNPAN/src/word_index/opt2/500word_list.txt"
mod3_pan = "/home/sukanya/PycharmProjects/SiameseNNPAN/src/word_index/opt3/500word_list.txt"
mod4_pan = "/home/sukanya/PycharmProjects/SiameseNNPAN/src/word_index/opt4/500word_list.txt"
mod1_koppel = "/home/sukanya/PycharmProjects/SiameseNetworkTensorflow/src/baseline_with_Spacy/word_index/opt1/500word_list.txt"
mod2_koppel = "/home/sukanya/PycharmProjects/SiameseNetworkTensorflow/src/baseline_with_Spacy/word_index/opt2/500word_list.txt"
mod3_koppel = "/home/sukanya/PycharmProjects/SiameseNetworkTensorflow/src/baseline_with_Spacy/word_index/opt3/500word_list.txt"
mod4_koppel = "/home/sukanya/PycharmProjects/SiameseNetworkTensorflow/src/baseline_with_Spacy/word_index/opt4/500word_list.txt"

# %%
def read_file(path):
    with open(path) as f:
        data = f.read()
    return data
text_mod1_pan = read_file(mod1_pan)
text_mod2_pan = read_file(mod2_pan)
text_mod3_pan = read_file(mod3_pan)
text_mod4_pan = read_file(mod4_pan)
text_mod1_koppel = read_file(mod1_koppel)
text_mod2_koppel = read_file(mod2_koppel)
text_mod3_koppel = read_file(mod3_koppel)
text_mod4_koppel = read_file(mod4_koppel)

# %%
def get_spacy_tokens(text):
    #nlp = English()
    #tkr = nlp.Defaults.create_tokenizer(nlp)
    #tkr(text.lower())
    nlp = spacy.load("en_core_web_sm") #English()
    nlp.max_length = 540000000 # needs to adjust
    doc = nlp(text.lower()) 
    return [token.text for token in doc]

tokens_mod1_pan = set(get_spacy_tokens(text_mod1_pan))
tokens_mod2_pan = set(get_spacy_tokens(text_mod2_pan))
tokens_mod3_pan = set(get_spacy_tokens(text_mod3_pan))
tokens_mod4_pan = set(get_spacy_tokens(text_mod4_pan))
tokens_mod1_koppel = set(get_spacy_tokens(text_mod1_koppel))
tokens_mod2_koppel = set(get_spacy_tokens(text_mod2_koppel))
tokens_mod3_koppel = set(get_spacy_tokens(text_mod3_koppel))
tokens_mod4_koppel = set(get_spacy_tokens(text_mod4_koppel))

# %%
def set1_common_set2(set1, set2):
    common = set1.intersection(set2)
    print("Number of common tokens", len(common))
    print("percentage of common", len(common)/len(set1))
    print("len of set1", len(set1))
    print("len of set2", len(set2))
    
set1_common_set2(tokens_mod4_pan, tokens_mod4_koppel)
# Out:
# Number of common tokens 263
# percentage of common 0.526
# len of set1 500
# len of set2 500

# %%
len(tokens_mod2_pan.intersection(tokens_mod2_koppel))
# Out:
# 261

# %%
len(tokens_mod3_pan)
# Out:
# 500

# %%
len(tokens_mod3_koppel)
# Out:
# 500
